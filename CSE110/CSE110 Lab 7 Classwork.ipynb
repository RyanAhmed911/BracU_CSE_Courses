# %% [markdown]
# Task 1

# %%
def even_checker(num):
    if num % 2 == 0:
        print("Even!!")
    else:
        print("Odd!!")

even_checker(2)
# Out:
# Even!!

# %% [markdown]
# Task 2

# %%
def fibonacci_checker(length):
    num1 = 0
    num2 = 1
    print(num1, end = " ")
    while num2 <= length:
        num3 = num1+num2
        print(num2, end = " ")
        num1 = num2
        num2 = num3

fibonacci_checker(10)
# Out:
# 0 1 1 2 3 5 8

# %% [markdown]
# Task 3

# %%
def foo_moo(num):
    if num % 2 == 0 and num % 3 == 0:
        return "FooMoo"
    elif num % 3 == 0:
        return "Moo"
    elif num % 2 == 0:
        return "Foo"
    else:
        return "Boo"

foo_moo(6)
# Out:
# 'FooMoo'

# %% [markdown]
# Task 4

# %%
def function_name(string):
    upper = 0
    lower = 0
    for i in string:
        if i.isupper() == True:
            upper += 1
        elif i.islower() == True:
            lower += 1
    print(f"No. of Uppercase characters : {upper}")
    print(f"No. of Lowercase Characters: {lower}")

function_name('HaRRy PotteR')
# Out:
# No. of Uppercase characters : 5
# No. of Lowercase Characters: 6

# %% [markdown]
# Task 5

# %%
age = int(input())
salary = int(input())
job = input().lower()

def calculate_tax(age,salary,job):
    if age < 18 or job == 'president' or salary < 10000:
        return 0
    elif 10000 <= salary <= 20000:
        tax = salary*5/100
        return tax
    elif salary > 20000:
        tax = salary*10/100
        return tax

calculate_tax(age,salary,job)
# Out:
# 20
# 22000
# assistant manager
# 2200.0

# %% [markdown]
# Task 6

# %%
days = int(input())

def function_name(days):

    year = days//365
    print(f"{year} years,", end = " ")

    months = (days-(year*365))//30
    print(f"{months} months and", end = " ")

    rem_days = days-(year*365)-(months*30)
    print(f"{rem_days} days")

function_name(days)
# Out:
# 4330
# 11 years, 10 months and 15 days

# %% [markdown]
# Task 7

# %%
def show_palindrome(num):
    string = ""
    for i in range(1,num):
        string += str(i)
    for i in range(num,0,-1):
        string += str(i)
    return string
print(show_palindrome(3))
# Out:
# 12321

# %% [markdown]
# Task 8

# %%
def show_palindromic_triangle(num):
    for i in range(1, num+1):
        for j in range(num-i):
            print(" ",end="")
        print(show_palindrome(i))
show_palindromic_triangle(5)
# Out:
#     1
#    121
#   12321
#  1234321
# 123454321

# %% [markdown]
# Task 9

# %%
import math
def area_circumference_generator(radius):
    area = math.pi*(radius**2)
    circumference = 2*math.pi*radius
    return (area,circumference)

print(area_circumference_generator(1.5))
x,y = area_circumference_generator(1.5)
print(f"Area of the circle is {x} and circumference is {y}")
# Out:
# (7.0685834705770345, 9.42477796076938)
# Area of the circle is 7.0685834705770345 and circumference is 9.42477796076938

# %% [markdown]
# Task 14

# %%
sentence = input().lstrip('"').rstrip('"')
position = int(input())

def function_name(sent,pos):
    new = ""
    remove = ""
    for i in range(len(sent)):
        if i == 0 or i % pos != 0:
            new += sent[i]
        elif i % pos == 0:
            remove += sent[i]
    result = new + remove
    return result

print(function_name(sentence, position))
# Out:
# "Python is easy to learn. I love python."
# 6
# Pythonis eay to earn.I lov pythn. sl eo

# %% [markdown]
# Task 15

# %%
order_items = input()
def shoppy(order,location = "Dhanmondi"):
    items = {'"Rice"':105,'"Potato"':20,'"Chicken"':250,'"Beef"':510,'"Oil"':85}
    total = 0
    list1 = order.lstrip("[").rstrip("]").split(", ")
    for i in list1:
        if i in items:
            total += items[i]
    if location == "Dhanmondi":
        total += 30
    else:
        total += 70
    return total

shoppy(order_items, "Mohakhali")
# Out:
# ["Rice", "Beef", "Rice"]
# 790

# %%
order = input()
list1 = order.lstrip("[").rstrip("]").split(", ")
list2 = []
for i in range(len(list1)):
    list2.append(list1[i].lstrip('"').rstrip('"'))
print(list2)
# Out:
# ["Rice", "Beef", "Rice"]
# ['Rice', 'Beef', 'Rice']

# %%
order = input()
word = ""
listy = []
for i in range(len(order)):
    if order[i] == "[" or order[i] == "," or order[i] == " " or order[i] == "]":
        continue
    elif order[i] == '"':
        if word != '':
            listy.append(word)
        word = ""
    else:
        word += order[i]

print(listy)
# Out:
# ["Rice", "Beef", "Rice"]
# ['Rice', 'Beef', 'Rice']
