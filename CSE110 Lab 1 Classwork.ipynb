# %% [markdown]
# Task 1

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# Task 2

# %%
print(54+56)
# Out:
# 110

# %% [markdown]
# Task 3

# %%
season = "Summer"
year = 2023

print(season)
print(year)
# Out:
# Summer
# 2023

# %% [markdown]
# Task 4

# %%
name = input("Enter your first name ")

print("Your name is",name)
# Out:
# Enter your first name John
# Your name is John

# %% [markdown]
# Task 5

# %%
M = int(input("M: "))
N = int(input("N: "))

print(str(M) + "^" + str(N) + ": " + str(M**N))
# Out:
# M: 2
# N: 3
# 2^3: 8

# %% [markdown]
# Task 6

# %%
total_weight = int(input("Total weight: "))
max = total_weight//4*4

print(max)
# Out:
# Total weight: 11
# 8

# %% [markdown]
# Task 7

# %%
A = int(input("A: "))
B = int(input("B: "))
C = int(input("C: "))
D = float(input("D: "))

print(int((A**C)+B*A-(D/3)))
# Out:
# A: 88
# B: 22
# C: 1
# D: 3.3
# 2022

# %% [markdown]
# Task 8

# %%
total_chocolate = int(input("Number of chocolate you have: "))
print("Each friend will receive",total_chocolate//3,"chocolates")
print("The number of remaining chocolates is",(total_chocolate%3))
# Out:
# Number of chocolate you have: 90
# Each friend will receive 30 chocolates
# The number of remaining chocolates is 0

# %% [markdown]
# Task 9

# %%
M = str(input())
N = str(input())

print(N+M)
# Out:
# Python
# 3
# 3Python

# %% [markdown]
# Task 10

# %%
a = int(input())
b = float(input())
c = int(input())

print("The inputs:",str(a)+",",str(b)+",",str(c))
print()
print("The result is",str(a+b)+str(c))
# Out:
# 33
# 1.9
# 753
# The inputs: 33, 1.9, 753
#
# The result is 34.9753

# %% [markdown]
# Task 11

# %%
number = int(input())

if number%2 == 0:
  print("True")

else:
  print("False")
# Out:
# -26
# True
